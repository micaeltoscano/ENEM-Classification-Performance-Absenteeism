# %%
import pandas as pd

# %%
df_2022 = pd.read_parquet("enem_parquet/2022")

# %%
df_2022
# Out:
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0        210057943671    2022               14       M                2
# 1        210057516120    2022               14       M                2
# 2        210057280536    2022                5       F                1
# 3        210055724397    2022                6       M                1
# 4        210055097896    2022                4       M                0
# ...               ...     ...              ...     ...              ...
# 3476100  210056490014    2022                3       F                1
# 3476101  210057345158    2022                3       M                1
# 3476102  210056006438    2022                2       F                1
# 3476103  210057209705    2022                4       F                1
# 3476104  210057031929    2022                3       F                1
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# ...

# %%
colunas_nao_usadas = [
    'NU_INSCRICAO', 'NU_ANO', 'TP_SEXO', 'TP_ESTADO_CIVIL', 
    'TP_NACIONALIDADE', 'TP_ANO_CONCLUIU', 'CO_MUNICIPIO_ESC', 
    'NO_MUNICIPIO_ESC', 'SG_UF_ESC', 'CO_MUNICIPIO_PROVA', 
    'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA', 
    
    'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC', 
    'CO_PROVA_MT', 'TP_LINGUA',
    
    'Q005', 'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 
    'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 
    'Q020', 'Q021', 'Q023'
]

df_2022.drop(columns=colunas_nao_usadas, inplace=True, errors='ignore')

# %%
df_2022.isna().sum()
# Out:
# TP_FAIXA_ETARIA                 0
# TP_COR_RACA                     0
# TP_ST_CONCLUSAO                 0
# TP_ESCOLA                       0
# TP_ENSINO                 2213361
# IN_TREINEIRO                    0
# CO_UF_ESC                 2524161
# TP_DEPENDENCIA_ADM_ESC    2524161
# TP_LOCALIZACAO_ESC        2524161
# TP_SIT_FUNC_ESC           2524161
# TP_PRESENCA_CN                  0
# TP_PRESENCA_CH                  0
# TP_PRESENCA_LC                  0
# TP_PRESENCA_MT                  0
# NU_NOTA_CN                1120710
# NU_NOTA_CH                 982663
# NU_NOTA_LC                 982663
# NU_NOTA_MT                1120710
# TX_RESPOSTAS_CN           1120710
# TX_RESPOSTAS_CH            982663
# TX_RESPOSTAS_LC            982663
# TX_RESPOSTAS_MT           1120710
# TX_GABARITO_CN            1120710
# TX_GABARITO_CH             982663
# TX_GABARITO_LC             982663
# TX_GABARITO_MT            1120710
# TP_STATUS_REDACAO          982663
# ...

# %%
df_2022 = df_2022.dropna()

# %%
df_2022.isna().sum()
# Out:
# TP_FAIXA_ETARIA           0
# TP_COR_RACA               0
# TP_ST_CONCLUSAO           0
# TP_ESCOLA                 0
# TP_ENSINO                 0
# IN_TREINEIRO              0
# CO_UF_ESC                 0
# TP_DEPENDENCIA_ADM_ESC    0
# TP_LOCALIZACAO_ESC        0
# TP_SIT_FUNC_ESC           0
# TP_PRESENCA_CN            0
# TP_PRESENCA_CH            0
# TP_PRESENCA_LC            0
# TP_PRESENCA_MT            0
# NU_NOTA_CN                0
# NU_NOTA_CH                0
# NU_NOTA_LC                0
# NU_NOTA_MT                0
# TX_RESPOSTAS_CN           0
# TX_RESPOSTAS_CH           0
# TX_RESPOSTAS_LC           0
# TX_RESPOSTAS_MT           0
# TX_GABARITO_CN            0
# TX_GABARITO_CH            0
# TX_GABARITO_LC            0
# TX_GABARITO_MT            0
# TP_STATUS_REDACAO         0
# NU_NOTA_COMP1             0
# NU_NOTA_COMP2             0
# NU_NOTA_COMP3             0
# NU_NOTA_COMP4             0
# NU_NOTA_COMP5             0
# NU_NOTA_REDACAO           0
# ...

# %%
df_2022
# Out:
#          TP_FAIXA_ETARIA  TP_COR_RACA  TP_ST_CONCLUSAO  TP_ESCOLA  TP_ENSINO  \
# 40                     5            3                2          2          1
# 55                     3            1                2          2          1
# 57                     2            3                2          2          1
# 59                     3            3                2          2          2
# 67                     3            1                2          2          1
# ...                  ...          ...              ...        ...        ...
# 3476077                2            3                2          2          1
# 3476090                3            1                2          3          1
# 3476094                3            3                2          2          1
# 3476095                2            1                2          2          1
# 3476098                3            1                2          2          1
#
# ...

# %%
df_2022['TP_STATUS_REDACAO'].value_counts()
# Out:
# TP_STATUS_REDACAO
# 1    649703
# 4     12768
# 3      8689
# 6      7423
# 8      2425
# 2       384
# 9       355
# 7       153
# Name: count, dtype: Int64

# %%
df_2022 = df_2022[df_2022['TP_STATUS_REDACAO'] == 1]

# %%
df_2022
# Out:
#          TP_FAIXA_ETARIA  TP_COR_RACA  TP_ST_CONCLUSAO  TP_ESCOLA  TP_ENSINO  \
# 40                     5            3                2          2          1
# 55                     3            1                2          2          1
# 57                     2            3                2          2          1
# 59                     3            3                2          2          2
# 67                     3            1                2          2          1
# ...                  ...          ...              ...        ...        ...
# 3476074                3            4                2          2          1
# 3476077                2            3                2          2          1
# 3476090                3            1                2          3          1
# 3476094                3            3                2          2          1
# 3476095                2            1                2          2          1
#
# ...

# %%
df_2022['IN_TREINEIRO'].value_counts()
# Out:
# IN_TREINEIRO
# 0    649703
# Name: count, dtype: Int64

# %%
df_2022['TP_PRESENCA_CN'].value_counts()
# Out:
# TP_PRESENCA_CN
# 1    649703
# Name: count, dtype: Int64

# %%
df_2022['TP_PRESENCA_CH'].value_counts()
# Out:
# TP_PRESENCA_CH
# 1    649703
# Name: count, dtype: Int64

# %%
df_2022['TP_ST_CONCLUSAO'].value_counts()
# Out:
# TP_ST_CONCLUSAO
# 2    649703
# Name: count, dtype: Int64

# %%
df_2022.to_parquet("dados2022_limpos")

# %%
import pandas as pd

# %%
df_2021 = pd.read_parquet("enem_parquet/2021")

# %%
df_2021
# Out:
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0        210053865474    2021                5       F                1
# 1        210052384164    2021               12       M                1
# 2        210052589243    2021               13       F                3
# 3        210052128335    2021                3       M                1
# 4        210051353021    2021                2       F                1
# ...               ...     ...              ...     ...              ...
# 3389827  210052571466    2021                9       M                1
# 3389828  210052207206    2021                3       F                2
# 3389829  210051224444    2021                2       M                1
# 3389830  210052150977    2021                5       F                1
# 3389831  210051984641    2021                5       F                1
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# ...

# %%
colunas_nao_usadas = [
    'NU_INSCRICAO', 'NU_ANO', 'TP_SEXO', 'TP_ESTADO_CIVIL', 
    'TP_NACIONALIDADE', 'TP_ANO_CONCLUIU', 'CO_MUNICIPIO_ESC', 
    'NO_MUNICIPIO_ESC', 'SG_UF_ESC', 'CO_MUNICIPIO_PROVA', 
    'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA', 
    
    'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC', 
    'CO_PROVA_MT', 'TP_LINGUA',
    
    'Q005', 'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 
    'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 
    'Q020', 'Q021', 'Q023'
]

df_2021.drop(columns=colunas_nao_usadas, inplace=True, errors='ignore')

# %%
df_2021.isna().sum()
# Out:
# TP_FAIXA_ETARIA                 0
# TP_COR_RACA                     0
# TP_ST_CONCLUSAO                 0
# TP_ESCOLA                       0
# TP_ENSINO                 2293004
# IN_TREINEIRO                    0
# CO_UF_ESC                 2576026
# TP_DEPENDENCIA_ADM_ESC    2576026
# TP_LOCALIZACAO_ESC        2576026
# TP_SIT_FUNC_ESC           2576026
# TP_PRESENCA_CN                  0
# TP_PRESENCA_CH                  0
# TP_PRESENCA_LC                  0
# TP_PRESENCA_MT                  0
# NU_NOTA_CN                1143988
# NU_NOTA_CH                1011453
# NU_NOTA_LC                1011453
# NU_NOTA_MT                1143988
# TX_RESPOSTAS_CN           1143988
# TX_RESPOSTAS_CH           1011453
# TX_RESPOSTAS_LC           1011453
# TX_RESPOSTAS_MT           1143988
# TX_GABARITO_CN            1143988
# TX_GABARITO_CH            1011453
# TX_GABARITO_LC            1011453
# TX_GABARITO_MT            1143988
# TP_STATUS_REDACAO         1011453
# ...

# %%
df_2021 = df_2021.dropna()

# %%
df_2021.isna().sum()
# Out:
# TP_FAIXA_ETARIA           0
# TP_COR_RACA               0
# TP_ST_CONCLUSAO           0
# TP_ESCOLA                 0
# TP_ENSINO                 0
# IN_TREINEIRO              0
# CO_UF_ESC                 0
# TP_DEPENDENCIA_ADM_ESC    0
# TP_LOCALIZACAO_ESC        0
# TP_SIT_FUNC_ESC           0
# TP_PRESENCA_CN            0
# TP_PRESENCA_CH            0
# TP_PRESENCA_LC            0
# TP_PRESENCA_MT            0
# NU_NOTA_CN                0
# NU_NOTA_CH                0
# NU_NOTA_LC                0
# NU_NOTA_MT                0
# TX_RESPOSTAS_CN           0
# TX_RESPOSTAS_CH           0
# TX_RESPOSTAS_LC           0
# TX_RESPOSTAS_MT           0
# TX_GABARITO_CN            0
# TX_GABARITO_CH            0
# TX_GABARITO_LC            0
# TX_GABARITO_MT            0
# TP_STATUS_REDACAO         0
# NU_NOTA_COMP1             0
# NU_NOTA_COMP2             0
# NU_NOTA_COMP3             0
# NU_NOTA_COMP4             0
# NU_NOTA_COMP5             0
# NU_NOTA_REDACAO           0
# ...

# %%
df_2021
# Out:
#          TP_FAIXA_ETARIA  TP_COR_RACA  TP_ST_CONCLUSAO  TP_ESCOLA  TP_ENSINO  \
# 3                      3            3                2          2          1
# 4                      2            3                2          2          1
# 33                     3            1                2          2          1
# 45                     4            3                2          2          1
# 51                     3            3                2          2          1
# ...                  ...          ...              ...        ...        ...
# 3389797                2            2                2          2          1
# 3389800                2            1                2          2          1
# 3389801                3            1                2          3          1
# 3389817                2            1                2          3          1
# 3389820                2            2                2          2          1
#
# ...

# %%
df_2021['TP_STATUS_REDACAO'].value_counts()
# Out:
# TP_STATUS_REDACAO
# 1    573892
# 4      8238
# 6      5679
# 3      1979
# 8      1299
# 9       408
# 2       408
# 7       286
# Name: count, dtype: Int64

# %%
df_2021 = df_2021[df_2021['TP_STATUS_REDACAO'] == 1]

# %%
df_2021
# Out:
#          TP_FAIXA_ETARIA  TP_COR_RACA  TP_ST_CONCLUSAO  TP_ESCOLA  TP_ENSINO  \
# 3                      3            3                2          2          1
# 4                      2            3                2          2          1
# 33                     3            1                2          2          1
# 45                     4            3                2          2          1
# 51                     3            3                2          2          1
# ...                  ...          ...              ...        ...        ...
# 3389778                3            3                2          2          1
# 3389793                2            1                2          3          1
# 3389797                2            2                2          2          1
# 3389800                2            1                2          2          1
# 3389817                2            1                2          3          1
#
# ...

# %%
df_2021['IN_TREINEIRO'].value_counts()
# Out:
# IN_TREINEIRO
# 0    573892
# Name: count, dtype: Int64

# %%
df_2021['TP_PRESENCA_CN'].value_counts()
# Out:
# TP_PRESENCA_CN
# 1    573892
# Name: count, dtype: Int64

# %%
df_2021['TP_PRESENCA_CH'].value_counts()
# Out:
# TP_PRESENCA_CH
# 1    573892
# Name: count, dtype: Int64

# %%
df_2021['TP_ST_CONCLUSAO'].value_counts()
# Out:
# TP_ST_CONCLUSAO
# 2    573892
# Name: count, dtype: Int64

# %%
df_2021.to_parquet("dados2021_limpos")

# %%
import pandas as pd

# %%
df_2019 = pd.read_parquet("enem_parquet/2019/")
df_2019_descricao = pd.read_csv("descricao.csv")

# %%
df_2019
# Out:
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0        190001595656    2019               13       M                1
# 1        190001421546    2019                8       M                1
# 2        190001133210    2019               13       F                1
# 3        190001199383    2019               10       F                1
# 4        190001237802    2019                7       F                1
# ...               ...     ...              ...     ...              ...
# 5095166  190003061751    2019                4       F                1
# 5095167  190003286152    2019                3       F                1
# 5095168  190003071099    2019               14       F                2
# 5095169  190003382827    2019                5       M                1
# 5095170  190002775679    2019                5       F                1
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_colwidth', None):
    display(df_2019_descricao)
# Out:
#                     Coluna  \
# 0             NU_INSCRICAO
# 1                   NU_ANO
# 2          TP_FAIXA_ETARIA
# 3                  TP_SEXO
# 4          TP_ESTADO_CIVIL
# 5              TP_COR_RACA
# 6         TP_NACIONALIDADE
# 7          TP_ST_CONCLUSAO
# 8          TP_ANO_CONCLUIU
# 9                TP_ESCOLA
# 10               TP_ENSINO
# 11            IN_TREINEIRO
# 12        CO_MUNICIPIO_ESC
# 13        NO_MUNICIPIO_ESC
# 14               CO_UF_ESC
# 15               SG_UF_ESC
# 16  TP_DEPENDENCIA_ADM_ESC
# 17      TP_LOCALIZACAO_ESC
# 18         TP_SIT_FUNC_ESC
# 19      CO_MUNICIPIO_PROVA
# 20      NO_MUNICIPIO_PROVA
# 21             CO_UF_PROVA
# 22             SG_UF_PROVA
# 23          TP_PRESENCA_CN
# 24          TP_PRESENCA_CH
# 25          TP_PRESENCA_LC
# 26          TP_PRESENCA_MT
# 27             CO_PROVA_CN
# 28             CO_PROVA_CH
# 29             CO_PROVA_LC
# 30             CO_PROVA_MT
# 31              NU_NOTA_CN
# 32              NU_NOTA_CH
# ...

# %%
colunas_nao_usadas = [
    'NU_INSCRICAO', 'NU_ANO', 'TP_SEXO', 'TP_ESTADO_CIVIL', 
    'TP_NACIONALIDADE', 'TP_ANO_CONCLUIU', 'CO_MUNICIPIO_ESC', 
    'NO_MUNICIPIO_ESC', 'SG_UF_ESC', 'CO_MUNICIPIO_PROVA', 
    'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA', 
    
    'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC', 
    'CO_PROVA_MT', 'TP_LINGUA',
    
    'Q005', 'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 
    'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 
    'Q020', 'Q021', 'Q023'
]

df_2019.drop(columns=colunas_nao_usadas, inplace=True, errors='ignore')

# %%
df_2019
# Out:
#          TP_FAIXA_ETARIA  TP_COR_RACA  TP_ST_CONCLUSAO  TP_ESCOLA  TP_ENSINO  \
# 0                     13            3                1          1       <NA>
# 1                      8            1                1          1          1
# 2                     13            3                1          1          1
# 3                     10            1                1          1       <NA>
# 4                      7            1                1          1          1
# ...                  ...          ...              ...        ...        ...
# 5095166                4            3                4          1       <NA>
# 5095167                3            3                2          2          1
# 5095168               14            1                1          1          1
# 5095169                5            1                1          1       <NA>
# 5095170                5            3                1          1          1
#
# ...

# %%
df_2019.isna().sum()
# Out:
# TP_FAIXA_ETARIA                 0
# TP_COR_RACA                     0
# TP_ST_CONCLUSAO                 0
# TP_ESCOLA                       0
# TP_ENSINO                 2217036
# IN_TREINEIRO                    0
# CO_UF_ESC                 3947784
# TP_DEPENDENCIA_ADM_ESC    3947784
# TP_LOCALIZACAO_ESC        3947784
# TP_SIT_FUNC_ESC           3947784
# TP_PRESENCA_CN                  0
# TP_PRESENCA_CH                  0
# TP_PRESENCA_LC                  0
# TP_PRESENCA_MT                  0
# NU_NOTA_CN                1384836
# NU_NOTA_CH                1172125
# NU_NOTA_LC                1172125
# NU_NOTA_MT                1384836
# TX_RESPOSTAS_CN           1384836
# TX_RESPOSTAS_CH           1172125
# TX_RESPOSTAS_LC           1172125
# TX_RESPOSTAS_MT           1384836
# TX_GABARITO_CN            1384836
# TX_GABARITO_CH            1172125
# TX_GABARITO_LC            1172125
# TX_GABARITO_MT            1384836
# TP_STATUS_REDACAO         1172126
# ...

# %%
df_2019 = df_2019.dropna()

# %%
df_2019.isna().sum()
# Out:
# TP_FAIXA_ETARIA           0
# TP_COR_RACA               0
# TP_ST_CONCLUSAO           0
# TP_ESCOLA                 0
# TP_ENSINO                 0
# IN_TREINEIRO              0
# CO_UF_ESC                 0
# TP_DEPENDENCIA_ADM_ESC    0
# TP_LOCALIZACAO_ESC        0
# TP_SIT_FUNC_ESC           0
# TP_PRESENCA_CN            0
# TP_PRESENCA_CH            0
# TP_PRESENCA_LC            0
# TP_PRESENCA_MT            0
# NU_NOTA_CN                0
# NU_NOTA_CH                0
# NU_NOTA_LC                0
# NU_NOTA_MT                0
# TX_RESPOSTAS_CN           0
# TX_RESPOSTAS_CH           0
# TX_RESPOSTAS_LC           0
# TX_RESPOSTAS_MT           0
# TX_GABARITO_CN            0
# TX_GABARITO_CH            0
# TX_GABARITO_LC            0
# TX_GABARITO_MT            0
# TP_STATUS_REDACAO         0
# NU_NOTA_COMP1             0
# NU_NOTA_COMP2             0
# NU_NOTA_COMP3             0
# NU_NOTA_COMP4             0
# NU_NOTA_COMP5             0
# NU_NOTA_REDACAO           0
# ...

# %%
df_2019
# Out:
#          TP_FAIXA_ETARIA  TP_COR_RACA  TP_ST_CONCLUSAO  TP_ESCOLA  TP_ENSINO  \
# 26                     2            1                2          3          1
# 28                     3            1                2          2          1
# 31                     2            2                2          2          1
# 34                     2            2                2          2          1
# 53                     3            3                2          2          1
# ...                  ...          ...              ...        ...        ...
# 5095143                2            3                2          2          1
# 5095151                3            4                2          2          1
# 5095152                2            3                2          2          1
# 5095158                3            3                2          2          1
# 5095162                2            1                2          3          1
#
# ...

# %%
df_2019['TP_STATUS_REDACAO'].value_counts()
# Out:
# TP_STATUS_REDACAO
# 1    880332
# 4     11087
# 6      7408
# 3      6641
# 8      1918
# 2       677
# 9       604
# 7       503
# Name: count, dtype: Int64

# %%
df_2019 = df_2019[df_2019['TP_STATUS_REDACAO'] == 1]

# %%
df_2019
# Out:
#          TP_FAIXA_ETARIA  TP_COR_RACA  TP_ST_CONCLUSAO  TP_ESCOLA  TP_ENSINO  \
# 26                     2            1                2          3          1
# 28                     3            1                2          2          1
# 31                     2            2                2          2          1
# 34                     2            2                2          2          1
# 53                     3            3                2          2          1
# ...                  ...          ...              ...        ...        ...
# 5095143                2            3                2          2          1
# 5095151                3            4                2          2          1
# 5095152                2            3                2          2          1
# 5095158                3            3                2          2          1
# 5095162                2            1                2          3          1
#
# ...

# %%
df_2019['IN_TREINEIRO'].value_counts()
# Out:
# IN_TREINEIRO
# 0    880332
# Name: count, dtype: Int64

# %%
df_2019['TP_ESCOLA'].value_counts()
# Out:
# TP_ESCOLA
# 2    756702
# 3    123630
# Name: count, dtype: Int64

# %%
df_2019['TP_ENSINO'].value_counts()
# Out:
# TP_ENSINO
# 1    878109
# 2      2223
# Name: count, dtype: Int64

# %%
df_2019['TP_PRESENCA_CN'].value_counts()
# Out:
# TP_PRESENCA_CN
# 1    880332
# Name: count, dtype: Int64

# %%
df_2019['TP_PRESENCA_CH'].value_counts()
# Out:
# TP_PRESENCA_CH
# 1    880332
# Name: count, dtype: Int64

# %%
df_2019['TP_ST_CONCLUSAO'].value_counts()
# Out:
# TP_ST_CONCLUSAO
# 2    880332
# Name: count, dtype: Int64

# %% [markdown]
# lembrete: se nos outros datasets uma coluna tiver apenas 1 valor como é o caso de algumas aqui, retire!

# %%
df_2019.to_parquet("dados2019_limpos")

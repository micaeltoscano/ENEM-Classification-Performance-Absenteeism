# %%
import pandas as pd

# %%
df_2020 = pd.read_parquet("enem_parquet/2020")

# %%
df_2020
# Out:
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0        200006271946    2020               11       F                1
# 1        200001195856    2020               11       M                2
# 2        200001943954    2020                4       F                2
# 3        200001908998    2020                2       M                1
# 4        200001634757    2020                4       F                1
# ...               ...     ...              ...     ...              ...
# 5783104  200004393462    2020                2       F                1
# 5783105  200003075563    2020                6       M                1
# 5783106  200005896891    2020                2       M                1
# 5783107  200001728973    2020                8       M                1
# 5783108  200005120080    2020                3       F                1
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# ...

# %%
colunas_nao_usadas = [
    'NU_INSCRICAO', 'NU_ANO', 'TP_SEXO', 'TP_ESTADO_CIVIL', 
    'TP_NACIONALIDADE', 'TP_ANO_CONCLUIU', 'CO_MUNICIPIO_ESC', 
    'NO_MUNICIPIO_ESC', 'SG_UF_ESC', 'CO_MUNICIPIO_PROVA', 
    'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA', 
    
    'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC', 
    'CO_PROVA_MT', 'TP_LINGUA',
    
    'Q005', 'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 
    'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 
    'Q020', 'Q021', 'Q023'
]

df_2020.drop(columns=colunas_nao_usadas, inplace=True, errors='ignore')

# %%
df_2020.isna().sum()
# Out:
# TP_FAIXA_ETARIA                 0
# TP_COR_RACA                     0
# TP_ST_CONCLUSAO                 0
# TP_ESCOLA                       0
# TP_ENSINO                 4479663
# IN_TREINEIRO                    0
# CO_UF_ESC                 4878540
# TP_DEPENDENCIA_ADM_ESC    4878540
# TP_LOCALIZACAO_ESC        4878540
# TP_SIT_FUNC_ESC           4878540
# TP_PRESENCA_CN                  0
# TP_PRESENCA_CH                  0
# TP_PRESENCA_LC                  0
# TP_PRESENCA_MT                  0
# NU_NOTA_CN                3185669
# NU_NOTA_CH                3028969
# NU_NOTA_LC                3028969
# NU_NOTA_MT                3185669
# TX_RESPOSTAS_CN           3185669
# TX_RESPOSTAS_CH           3028969
# TX_RESPOSTAS_LC           3028969
# TX_RESPOSTAS_MT           3185669
# TX_GABARITO_CN            3185669
# TX_GABARITO_CH            3028969
# TX_GABARITO_LC            3028969
# TX_GABARITO_MT            3185669
# TP_STATUS_REDACAO         3028969
# ...

# %%
df_2020 = df_2020.dropna()

# %%
df_2020.isna().sum()
# Out:
# TP_FAIXA_ETARIA           0
# TP_COR_RACA               0
# TP_ST_CONCLUSAO           0
# TP_ESCOLA                 0
# TP_ENSINO                 0
# IN_TREINEIRO              0
# CO_UF_ESC                 0
# TP_DEPENDENCIA_ADM_ESC    0
# TP_LOCALIZACAO_ESC        0
# TP_SIT_FUNC_ESC           0
# TP_PRESENCA_CN            0
# TP_PRESENCA_CH            0
# TP_PRESENCA_LC            0
# TP_PRESENCA_MT            0
# NU_NOTA_CN                0
# NU_NOTA_CH                0
# NU_NOTA_LC                0
# NU_NOTA_MT                0
# TX_RESPOSTAS_CN           0
# TX_RESPOSTAS_CH           0
# TX_RESPOSTAS_LC           0
# TX_RESPOSTAS_MT           0
# TX_GABARITO_CN            0
# TX_GABARITO_CH            0
# TX_GABARITO_LC            0
# TX_GABARITO_MT            0
# TP_STATUS_REDACAO         0
# NU_NOTA_COMP1             0
# NU_NOTA_COMP2             0
# NU_NOTA_COMP3             0
# NU_NOTA_COMP4             0
# NU_NOTA_COMP5             0
# NU_NOTA_REDACAO           0
# ...

# %%
df_2020
# Out:
#          TP_FAIXA_ETARIA  TP_COR_RACA  TP_ST_CONCLUSAO  TP_ESCOLA  TP_ENSINO  \
# 36                     3            3                2          2          1
# 65                     3            3                2          2          1
# 84                     2            3                2          2          1
# 89                     2            1                2          2          1
# 93                     4            2                2          2          1
# ...                  ...          ...              ...        ...        ...
# 5783089                2            1                2          3          1
# 5783093                3            3                2          2          1
# 5783096                3            0                2          2          1
# 5783101                2            1                2          2          1
# 5783106                2            1                2          3          1
#
# ...

# %%
df_2020['TP_STATUS_REDACAO'].value_counts()
# Out:
# TP_STATUS_REDACAO
# 1    509871
# 4      4104
# 6      2749
# 3      2199
# 8       760
# 9       417
# 2       387
# 7       250
# Name: count, dtype: Int64

# %%
df_2020 = df_2020[df_2020['TP_STATUS_REDACAO'] == 1]

# %%
df_2020
# Out:
#          TP_FAIXA_ETARIA  TP_COR_RACA  TP_ST_CONCLUSAO  TP_ESCOLA  TP_ENSINO  \
# 36                     3            3                2          2          1
# 65                     3            3                2          2          1
# 84                     2            3                2          2          1
# 89                     2            1                2          2          1
# 93                     4            2                2          2          1
# ...                  ...          ...              ...        ...        ...
# 5783089                2            1                2          3          1
# 5783093                3            3                2          2          1
# 5783096                3            0                2          2          1
# 5783101                2            1                2          2          1
# 5783106                2            1                2          3          1
#
# ...

# %%
df_2020['IN_TREINEIRO'].value_counts()
# Out:
# IN_TREINEIRO
# 0    509871
# Name: count, dtype: Int64

# %%
df_2020['TP_PRESENCA_CN'].value_counts()
# Out:
# TP_PRESENCA_CN
# 1    509871
# Name: count, dtype: Int64

# %%
df_2020['TP_PRESENCA_CH'].value_counts()
# Out:
# TP_PRESENCA_CH
# 1    509871
# Name: count, dtype: Int64

# %%
df_2020['TP_ST_CONCLUSAO'].value_counts()
# Out:
# TP_ST_CONCLUSAO
# 2    509871
# Name: count, dtype: Int64

# %%
df_2020.to_parquet("dados2020_limpos")
